# %%
import numpy as np
# from utils import *
import utils
import importlib
import matplotlib.pyplot as plt
import itertools
importlib.reload(utils)
# Out:
# <module 'utils' from '/home/yamamoto/Dropbox/study/montecarlo/ising/single/utils.py'>

# %%
p = {'t': 1, 'J': 1.0, 'L': 100, 'ntot': 100, 'measure_interval': 1}
ms = []
evars = []
trange = 100
tmax = 4.0
ts = [0.1+tmax*i/trange for i in range(trange)]
for t in ts:
    p['t'] = t
    smc = utils.Mc(**p)
    spins, Mzs, energys = smc.mc_sw()
    ms.append(np.mean(np.abs(Mzs[energys.shape[0]//4:])))
    evars.append(np.var(energys[energys.shape[0]//4:]))
    # ms.append(np.abs(np.mean(Mzs)))
    # evars.append(np.var(energys))

# %%
fig, ax = plt.subplots()
ax.plot(ts, evars)

# %%
fig, ax = plt.subplots()
ax.plot(ts, ms)

# %%
p = {'t': 1, 'J': 1.0, 'L': 100, 'ntot': 1000, 'measure_interval': 1000}
smc = utils.Mc(**p)
spins, Mzs, energys = smc.mc_single()

# %%
p = {'t': 1, 'J': 1.0, 'L': 20, 'ntot': 10000, 'measure_interval': 1000}
ms = []
evars = []
trange = 100
tmax = 4.0
ts = [0.1+tmax*i/trange for i in range(trange)]
for t in ts:
    p['t'] = t
    smc = utils.Mc(**p)
    spins, Mzs, energys = smc.mc_single()
    ms.append(np.mean(np.abs(Mzs[energys.shape[0]//2:])))
    evars.append(np.var(energys[energys.shape[0]//2:]))

# %%
energys
# Out:
# array([  40., -336., -368., ..., -488., -392., -528.])

# %%
fig, ax = plt.subplots()
ax.plot(ts, ms)

# %%
fig, ax = plt.subplots()
ax.plot(ts, evars)
